# %% [markdown]
# https://auth0.com/blog/sqlalchemy-orm-tutorial-for-python-developers/

# %%
#from sqlalchemy import create_engine
#engine = create_engine('mysql://pythonuser:pythonuser@localhost:5432/RubyDB')

# %% [markdown]
# CREATE TABLE `limit_displays` (
#   `id` int NOT NULL AUTO_INCREMENT,
#   `limit_id` int DEFAULT NULL,
#   `plot_id` int DEFAULT NULL,
#   `color` varchar(255) DEFAULT 'k',
#   `style` varchar(255) DEFAULT 'line',
#   `created_at` datetime DEFAULT NULL,
#   `updated_at` datetime DEFAULT NULL,
#   PRIMARY KEY (`id`)
# ) ENGINE=InnoDB AUTO_INCREMENT=24922 DEFAULT CHARSET=utf8mb3;

# %% [markdown]
# class cls_limit_displays(Base):
#     __tablename__ = 'limit_displays'
#     id=Column(Integer, primary_key=True)
#     limit_id = Column('limit_id', Integer),
#     plot_id = Column('plot_id', Integer),
#     color  = Column('color',String(255)),
#     style  = Column('style', String(255)),
#     created_at = Column('created_at', DateTime),
#     updated_at = Column('updated_at', DateTime)
#
#     #title=Column('title', String(32))
#     #in_stock=Column('in_stock', Boolean)
#     #quantity=Column('quantity', Integer)
#     #price=Column('price', Numeric)

# %%
# coding=utf-8

# 1 - imports
from limits_display import cls_limit_displays
from base import Session

# 2 - extract a session
session = Session()

# 3 - extract all movies
limits_displays = session.query(cls_limit_displays).all()

# 4 - print movies' details
print('\n### All limits:')
for ld in limits_displays:
    #print(f'{ld.limit_id}')
    print(ld.color)
print('')
# Out:
# ### All limits:
# k
# r
# dkg
# k
# k
# ltg
# ltr
# k
# b
# ltr
# dkg
# k
# ltb
# c
# g10
# g20
# ltr
# dkb
# dkg
# dkr
# g
# ltg
# m
# r
# g60
# g80
# g90
# k
# k
# dkg
# k
# r
# b
# m
# k
# k
# ltr
# dkr
# c
# b
# dkb
# dkg
# r
# g60
# dkb
# dkg
# dkr
# g60
# dkb
# dkr
# dkg
# g30
# g30
# k
# ltb
# ltg
# k
# c
# r
# b
# dkg
# dkr
# ltg
# dkb
# k
# ltg
# k
# k
# k
# k
# k
# k
# ltg
# ltr
# b
# dkb
# b
# dkb
# dkg
# dkr
# r
# ltr
# k
# m
# g
# ltg
# c
# k
# r
# dkb
# ltb
# c
# y
# k
# dkr
# b
# b
# c
# g10
# g
# k
# m
# k
# b
# c
# g20
# g
# m
# dkr
# ltr
# ltg
# dkg
# dkr
# b
# ltg
# g
# ltg
# g
# ltb
# b
# dkb
# b
# dkb
# m
# dkr
# k
# r
# b
# ltr
# g10
# ltb
# dkg
# ltb
# y
# ltr
# ltb
# c
# g
# k
# k
# k
# k
# k
# g60
# k
# k
# k
# k
# k
# k
# k
# k
# k
# k
# k
# r
# r
# r
# b
# ltb
# k
# dkg
# dkb
# c
# m
# k
# c
# dkg
# dkr
# dkr
# k
# ltr
# c
# dkg
# m
# dkr
# dkb
# dkb
# k
# ltg
# k
# k
# k
# dkb
# k
# k
# k
# r
# g
# k
# ltb
# dkr
# r
# k
# c
# dkr
# g
# m
# c
# ltg
# dkb
# ...
